# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('./Raw Data Centraline_20220504_2035.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                               Name  \
# 0         551                   Victory Court・Lower Floor・Flat D
# 1         552                        Parker33・Upper Floor・Flat B
# 2         553          The Long Beach・Tower 6・Upper Floor・Flat A
# 3         554  Lohas Park・Phase 9B Grand Marini・Tower 2 (2A)・...
# 4         555  Lohas Park・Phase 7A Montara・Tower 2 (2A)・Upper...
#
#                   Adress       SA        Date    Rent
# 0  Tsuen Wan Town Centre  391 ft²  2022-04-30  12,500
# 1             Sai Wan Ho  210 ft²  2022-04-30  10,800
# 2        Olympic Station  548 ft²  2022-04-30  21,500
# 3             Lohas Park  807 ft²  2022-04-30  26,800
# 4             Lohas Park  775 ft²  2022-04-30  21,000

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# Name          object
# Adress        object
# SA            object
# Date          object
# Rent          object
# dtype: object

# %%
#drop NA columns and rows
df = df.drop(columns=['Unnamed: 0'], axis=1)
df = df.dropna(axis=0)
#rename columns
df = df.rename(columns={"Rent": "Price(HK$)", "SA": "SA (ft2)","Adress": "District"})

# %%
#convert date to datetime format
df["NDate"] = pd.to_datetime(df["Date"],dayfirst=True,exact=False)
df = df.drop(columns=['Date'], axis=1)
df = df.rename(columns={"NDate": "Date"})

# %%
#add a new floor column
def floor_change(x):
    if "Lower" in x:
        return "L"
    elif "Middle" in x:
        return "M"
    elif "Upper" in x:
        return "H"
    else:
        return "Others"
    
df["Floor"] = df["Name"].apply(lambda x: floor_change(x))

# %%
#convect SA (ft2), Price(HK$) to int
for i in ['SA (ft2)', 'Price(HK$)']:
    df[i] = df[i].str.replace(r'\D', '')
    df[i] = df[i].astype(int)

#add a new column of unit rent
df["Price/ft2(SA)"] = round(df["Price(HK$)"]/df["SA (ft2)"],2)
# Out:
# C:\Users\HiuC Lau\AppData\Local\Temp\ipykernel_19596\1230595599.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[i] = df[i].str.replace(r'\D', '')

# %%
index_names = df[(df['Floor'] == "")|(df['Date'] >= "2022-05-01")].index
# drop these row indexes
# from dataFrame
df.drop(index_names, inplace = True)

# %%
def estate(x):
    try: result = re.search(r'(\w+\s)*\w+\s*・',x).group().replace('・','')
    except: result = x
    return result
df['Estate'] = df['Name'].apply(estate)

# %%
import requests
import json

# %%
#Find district from estate
headers ={"Accept": "application/json", "Accept-Language" : "en"}
url = "https://www.als.ogcio.gov.hk/lookup"

districts =[]

for i in df['Estate']:
    address = i
    params = {"q":address}
    res = requests.get(url, params=params, headers=headers)
    d = json.loads(res.text)
    try: dist = d['SuggestedAddress'][0]['Address']['PremisesAddress']['EngPremisesAddress']['EngDistrict']['DcDistrict']
    except: dist = 'None'
    districts.append(dist)

# %%
df['District1'] = districts

# %%
index_nodis = df[df['District1'] == 'None'].index

# %%
#find district by address instead of estate
headers ={"Accept": "application/json", "Accept-Language" : "en"}
url = "https://www.als.ogcio.gov.hk/lookup"

for i in index_nodis:
    address = df.at[i,'District']
    params = {"q":address}
    res = requests.get(url, params=params, headers=headers)
    d = json.loads(res.text)
    try: dist = d['SuggestedAddress'][0]['Address']['PremisesAddress']['EngPremisesAddress']['EngDistrict']['DcDistrict']
    except: dist = 'None'
    
    df.at[i,'District1'] = dist

# %%
df['District1'] = df['District1'].str.replace(' DISTRICT','')

# %%
df = df.drop(columns=['Name','Estate'], axis=1)
df
# Out:
#                               District  SA (ft2)  Price(HK$)       Date  \
# 0                Tsuen Wan Town Centre       391       12500 2022-04-30
# 1                           Sai Wan Ho       210       10800 2022-04-30
# 2                      Olympic Station       548       21500 2022-04-30
# 3                           Lohas Park       807       26800 2022-04-30
# 4                           Lohas Park       775       21000 2022-04-30
# ...                                ...       ...         ...        ...
# 9436  Pak Shek Kok | Tai Po Mid-levels       915       23000 2021-10-05
# 9437                         Luk Yeung       445       14000 2021-10-05
# 9438                Nam Cheong Station       379       19500 2021-10-05
# 9439                        Lohas Park       793       23000 2021-10-05
# 9440                       So Kwun Wat       233        7800 2021-10-05
#
#        Floor  Price/ft2(SA)      District1
# 0          L          31.97     KWAI TSING
# 1          H          51.43        EASTERN
# 2          H          39.23  YAU TSIM MONG
# 3          M          33.21       SAI KUNG
# 4          H          27.10       SAI KUNG
# ...      ...            ...            ...
# 9436  Others          25.14         TAI PO
# 9437       L          31.46      TSUEN WAN
# 9438       M          51.45   SHAM SHUI PO
# 9439       L          29.00       SAI KUNG
# 9440       H          33.48       TUEN MUN
#
# [9385 rows x 7 columns]

# %%
df.to_csv("cleaned_Raw Data Centraline_20220504_2035(+18dis).csv", index = False)

# %%
df
# Out:
#                               District  SA (ft2)  Price(HK$)       Date  \
# 0                Tsuen Wan Town Centre       391       12500 2022-04-30
# 1                           Sai Wan Ho       210       10800 2022-04-30
# 2                      Olympic Station       548       21500 2022-04-30
# 3                           Lohas Park       807       26800 2022-04-30
# 4                           Lohas Park       775       21000 2022-04-30
# ...                                ...       ...         ...        ...
# 9436  Pak Shek Kok | Tai Po Mid-levels       915       23000 2021-10-05
# 9437                         Luk Yeung       445       14000 2021-10-05
# 9438                Nam Cheong Station       379       19500 2021-10-05
# 9439                        Lohas Park       793       23000 2021-10-05
# 9440                       So Kwun Wat       233        7800 2021-10-05
#
#        Floor  Price/ft2(SA)      District1
# 0          L          31.97     KWAI TSING
# 1          H          51.43        EASTERN
# 2          H          39.23  YAU TSIM MONG
# 3          M          33.21       SAI KUNG
# 4          H          27.10       SAI KUNG
# ...      ...            ...            ...
# 9436  Others          25.14         TAI PO
# 9437       L          31.46      TSUEN WAN
# 9438       M          51.45   SHAM SHUI PO
# 9439       L          29.00       SAI KUNG
# 9440       H          33.48       TUEN MUN
#
# [9385 rows x 7 columns]

# %%
df1 = pd.read_csv("cleaned_cnp 3-yrs_web-scrap (+18dis).csv")

# %%
pd.concat([df,df1]).reset_index().drop('index',axis=1)
# Out:
#                    District  SA (ft2)  Price(HK$)                 Date Floor  \
# 0     Tsuen Wan Town Centre       391       12500  2022-04-30 00:00:00     L
# 1                Sai Wan Ho       210       10800  2022-04-30 00:00:00     H
# 2           Olympic Station       548       21500  2022-04-30 00:00:00     H
# 3                Lohas Park       807       26800  2022-04-30 00:00:00     M
# 4                Lohas Park       775       21000  2022-04-30 00:00:00     H
# ...                     ...       ...         ...                  ...   ...
# 9906               Yau Tong       687       22500           2021-10-06     M
# 9907               Yau Tong       517       16300           2021-10-06     M
# 9908          Tseung Kwan O       364       15000           2021-10-05     H
# 9909          Tseung Kwan O       484       14500           2021-10-05     L
# 9910          Tseung Kwan O       501       15500           2021-10-05     H
#
#       Price/ft2(SA)      District1
# 0             31.97     KWAI TSING
# 1             51.43        EASTERN
# 2             39.23  YAU TSIM MONG
# 3             33.21       SAI KUNG
# 4             27.10       SAI KUNG
# ...             ...            ...
# 9906          32.75      KWUN TONG
# 9907          31.53      KWUN TONG
# 9908          41.21       SAI KUNG
# 9909          29.96       SAI KUNG
# 9910          30.94       SAI KUNG
#
# [9911 rows x 7 columns]

# %%
df.to_csv("fulldata(+18dis).csv", index = False)
